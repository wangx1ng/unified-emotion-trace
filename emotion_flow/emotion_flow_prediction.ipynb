# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
import tensorflow as tf
import pandas as pd

# %%
emo_overall_df = pd.read_csv('/gdrive/My Drive/Datasets/ef_vec_overall.csv', index_col=[0])
emo_10_df = pd.read_csv('/gdrive/My Drive/Datasets/ef_vec_10.csv', index_col=[0])
emo_20_df = pd.read_csv('/gdrive/My Drive/Datasets/ef_vec_20.csv',index_col=[0])
emo_30_df = pd.read_csv('/gdrive/My Drive/Datasets/ef_vec_30.csv', index_col=[0])
emo_50_df = pd.read_csv('/gdrive/My Drive/Datasets/ef_vec_50.csv', index_col=[0])

inten_overall_df = pd.read_csv('/gdrive/My Drive/Datasets/ef_inten_overall.csv', index_col=[0])
inten_10_df = pd.read_csv('/gdrive/My Drive/Datasets/ef_inten_10.csv', index_col=[0])
inten_20_df = pd.read_csv('/gdrive/My Drive/Datasets/ef_inten_20.csv', index_col=[0])
inten_30_df = pd.read_csv('/gdrive/My Drive/Datasets/ef_inten_30.csv', index_col=[0])
inten_50_df = pd.read_csv('/gdrive/My Drive/Datasets/ef_inten_50.csv', index_col=[0])

# %%
emo_overall_df.head()
# Out:
#                                                title  ...   trust
# 0                    4097_alice+of+old+vincennes.txt  ...  0.1927
# 1  17053_kate+bonnet+the+romance+of+a+pirate's+da...  ...  0.1877
# 2                           22002_a+simple+story.txt  ...  0.2257
# 3                        28862_the+time+of+roses.txt  ...  0.1968
# 4                          25727_vagabondia+1884.txt  ...  0.1864
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Preparing train data and test data

# %%
import numpy as np

# %%
# Labels for lstm
y = pd.get_dummies(emo_overall_df['label']).values
y.shape
# Out:
# (1003, 2)

# %%
# Single value labels
y_single = np.array(emo_overall_df.loc[:, ['label']])
y_single.shape
# Out:
# (1003, 1)

# %%
# Genre genre labels for lstm
y_genre = pd.get_dummies(emo_overall_df['genre']).values
y_genre.shape
# Out:
# (1003, 8)

# %%
# Single value genre labels
y_genre_single = np.array(emo_overall_df.loc[:, ['genre']])
y_genre_single.shape
# Out:
# (1003, 1)

# %%
# Prepare X train data
train_list = list()
train1d_list = list()

# %%
X_all = np.array(emo_overall_df.iloc[:, 3:12])
train1d_list.append(X_all)
n_samples = X_all.shape[0]
X_all = X_all.reshape(n_samples, 1, 8)
train_list.append(X_all)
X_all.shape
# Out:
# (1003, 1, 8)

# %%
X_10 = np.array(emo_10_df.iloc[:, 3:])
train1d_list.append(X_10)
n_samples = X_10.shape[0]
X_10 = X_10.reshape(n_samples, 10, 8)
train_list.append(X_10)
X_10.shape
# Out:
# (1003, 10, 8)

# %%
X_20 = np.array(emo_20_df.iloc[:, 3:])
train1d_list.append(X_20)
n_samples = X_20.shape[0]
X_20 = X_20.reshape(n_samples, 20, 8)
train_list.append(X_20)
X_20.shape
# Out:
# (1003, 20, 8)

# %%
X_30 = np.array(emo_30_df.iloc[:, 3:])
train1d_list.append(X_30)
n_samples = X_30.shape[0]
X_30 = X_30.reshape(n_samples, 30, 8)
train_list.append(X_30)
X_30.shape
# Out:
# (1003, 30, 8)

# %%
# X_50 = np.array(emo_50_df.iloc[:, 3:])
# train1d_list.append(X_50)
# n_samples = X_50.shape[0]
# X_50 = X_50.reshape(n_samples, 50, 8)
# train_list.append(X_50)
# X_50.shape

# %%
X_inten = np.array(inten_overall_df.iloc[:, 3:])
train1d_list.append(X_inten)
n_samples = X_inten.shape[0]
X_inten = X_inten.reshape(n_samples, 1, 8)
train_list.append(X_inten)
X_inten.shape
# Out:
# (1003, 1, 8)

# %%
X_inten_10 = np.array(inten_10_df.iloc[:, 3:])
train1d_list.append(X_inten_10)
n_samples = X_inten_10.shape[0]
X_inten_10 = X_inten_10.reshape(n_samples, 10, 8)
train_list.append(X_inten_10)
X_inten_10.shape
# Out:
# (1003, 10, 8)

# %%
X_inten_20 = np.array(inten_20_df.iloc[:, 3:])
train1d_list.append(X_inten_20)
n_samples = X_inten_20.shape[0]
X_inten_20 = X_inten_20.reshape(n_samples, 20, 8)
train_list.append(X_inten_20)
X_inten_20.shape
# Out:
# (1003, 20, 8)

# %%
X_inten_30 = np.array(inten_30_df.iloc[:, 3:])
train1d_list.append(X_inten_30)
n_samples = X_inten_30.shape[0]
X_inten_30 = X_inten_30.reshape(n_samples, 30, 8)
train_list.append(X_inten_30)
X_inten_30.shape
# Out:
# (1003, 30, 8)

# %%
# X_inten_50 = np.array(inten_50_df.iloc[:, 3:])
# train1d_list.append(X_inten_50)
# n_samples = X_inten_50.shape[0]
# X_inten_50 = X_inten_50.reshape(n_samples, 50, 8)
# train_list.append(X_inten_50)
# X_inten_50.shape

# %% [markdown]
# ## Training vectors with LSTM

# %%
# Attention GRU network 
from tensorflow.keras.layers import Dense, Lambda, dot, Activation, concatenate


def attention_3d_block(hidden_states):
    """
    Many-to-one attention mechanism for Keras.
    @param hidden_states: 3D tensor with shape (batch_size, time_steps, input_dim).
    @return: 2D tensor with shape (batch_size, 128)
    @author: felixhao28.
    """
    hidden_size = int(hidden_states.shape[2])
    # Inside dense layer
    #              hidden_states            dot               W            =>           score_first_part
    # (batch_size, time_steps, hidden_size) dot (hidden_size, hidden_size) => (batch_size, time_steps, hidden_size)
    # W is the trainable weight matrix of attention Luong's multiplicative style score
    score_first_part = Dense(hidden_size, use_bias=False, name='attention_score_vec')(hidden_states)
    #            score_first_part           dot        last_hidden_state     => attention_weights
    # (batch_size, time_steps, hidden_size) dot   (batch_size, hidden_size)  => (batch_size, time_steps)
    h_t = Lambda(lambda x: x[:, -1, :], output_shape=(hidden_size,), name='last_hidden_state')(hidden_states)
    score = dot([score_first_part, h_t], [2, 1], name='attention_score')
    attention_weights = Activation('softmax', name='attention_weight')(score)
    # (batch_size, time_steps, hidden_size) dot (batch_size, time_steps) => (batch_size, hidden_size)
    context_vector = dot([hidden_states, attention_weights], [1, 1], name='context_vector')
    pre_activation = concatenate([context_vector, h_t], name='attention_output')
    attention_vector = Dense(128, use_bias=False, activation='tanh', name='attention_vector')(pre_activation)
    return attention_vector

# %%
from tensorflow.keras import layers
import keras.backend as K

def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

def buildClassLSTM(X_train, n_units, n_classes):
  model = tf.keras.Sequential()
  model.add(layers.LSTM(
    units=n_units,
    input_shape=(X_train.shape[1], X_train.shape[2]),
    return_sequences=True
  ))
  model.add(layers.Dropout(0.15))
  model.add(layers.LSTM(units = 128, recurrent_dropout=0.2, return_sequences=True))
  model.add(layers.Dropout(0.15))
  model.add(layers.Dense(n_classes, activation='softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', get_f1])
  return model

def buildAttLSTM(X_train, n_units, n_classes):
  i = tf.keras.Input(shape=(X_train.shape[1], X_train.shape[2]))
  x = layers.LSTM(
    units=n_units,
    return_sequences=True
  )(i)
  x = layers.Dropout(0.15)(x)
  x = layers.LSTM(units = 128, recurrent_dropout=0.2, return_sequences=True)(x)
  x = attention_3d_block(x)
  x = layers.Dropout(0.15)(x)
  x = layers.Dense(n_classes, activation='softmax')(x)
  model = tf.keras.Model(inputs=[i], outputs=[x])
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', get_f1])
  return model

def buildAttGRU(X_train, n_units, n_classes):
  i = tf.keras.Input(shape=(X_train.shape[1], X_train.shape[2]))
  x = layers.GRU(
    units=n_units,
    return_sequences=True
  )(i)
  x = layers.Dropout(0.15)(x)
  x = layers.GRU(units = 128, recurrent_dropout=0.2, return_sequences=True)(x)
  x = attention_3d_block(x)
  x = layers.Dropout(0.15)(x)
  x = layers.Dense(n_classes, activation='softmax')(x)
  model = tf.keras.Model(inputs=[i], outputs=[x])
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', get_f1])
  return model

def buildClassGRU(X_train, n_units, n_classes):
  model = tf.keras.Sequential()
  model.add(layers.GRU(
    units=n_units,
    input_shape=(X_train.shape[1], X_train.shape[2]),
    return_sequences = True
  ))
  model.add(layers.Dropout(0.15))
  model.add(layers.GRU(units = 128, recurrent_dropout=0.2, return_sequences=True))
  model.add(layers.Dropout(0.15))
  model.add(layers.Dense(n_classes, activation='softmax'))
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', get_f1])
  return model
# Out:
# Using TensorFlow backend.

# %%
from sklearn.model_selection import train_test_split

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)

# %%
label_rst_LSTM = list()
for train in train_list:
  X_train, X_test, y_train, y_test = train_test_split(train, y, test_size=0.3, random_state=73)
  model = buildAttLSTM(X_train, 512, 2)
  # %time model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test), callbacks=[es], verbose=0)
  label_rst_LSTM.append(model.evaluate(X_test, y_test))
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# CPU times: user 20 s, sys: 2.54 s, total: 22.6 s
# Wall time: 21.1 s
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6307 - accuracy: 0.6445 - get_f1: 0.6337
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# CPU times: user 53.7 s, sys: 6 s, total: 59.7 s
# Wall time: 39.5 s
# 10/10 [==============================] - 0s 7ms/step - loss: 0.6207 - accuracy: 0.6645 - get_f1: 0.6478
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# CPU times: user 1min 49s, sys: 12.8 s, total: 2min 2s
# Wall time: 1min 19s
# ...

# %%
for rst in label_rst_LSTM:
  print(rst)
# Out:
# [0.6307129263877869, 0.644518256187439, 0.6336537599563599]
# [0.6207446455955505, 0.6644518375396729, 0.6478365063667297]
# [0.6142451763153076, 0.6677740812301636, 0.6600961089134216]
# [0.6337533593177795, 0.6544850468635559, 0.6430287957191467]
# [0.6174224019050598, 0.6644518375396729, 0.6524037718772888]
# [0.6130721569061279, 0.6877076625823975, 0.665144145488739]
# [0.6031668782234192, 0.6910299062728882, 0.6774038076400757]
# [0.6264456510543823, 0.6578072905540466, 0.6415864825248718]

# %%
label_rst_GRU = list()
label_models = list()
for train in train_list:
  X_train, X_test, y_train, y_test = train_test_split(train, y, test_size=0.3, random_state=73)
  model = buildAttGRU(X_train, 512, 2)
  # %time model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test), callbacks=[es], verbose=0)
  label_rst_GRU.append(model.evaluate(X_test, y_test))
  label_models.append(model)
# Out:
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# CPU times: user 16.6 s, sys: 1.69 s, total: 18.3 s
# Wall time: 13.5 s
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6202 - accuracy: 0.6445 - get_f1: 0.6291
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# CPU times: user 54.8 s, sys: 6.02 s, total: 1min
# Wall time: 39.9 s
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6394 - accuracy: 0.6611 - get_f1: 0.6493
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# CPU times: user 1min 34s, sys: 10.7 s, total: 1min 45s
# Wall time: 1min 7s
# ...

# %%
for rst in label_rst_GRU:
    print(rst)
# Out:
# [0.6201612949371338, 0.644518256187439, 0.6290864944458008]
# [0.6394106149673462, 0.6611295938491821, 0.6492787599563599]
# [0.5986226201057434, 0.6943521499633789, 0.6805287599563599]
# [0.7660311460494995, 0.6611295938491821, 0.6584134101867676]
# [0.6137391924858093, 0.6611295938491821, 0.6447114944458008]
# [0.620694637298584, 0.6611295938491821, 0.6492787599563599]
# [0.606188178062439, 0.7076411843299866, 0.6975961327552795]
# [0.6683012247085571, 0.6710963249206543, 0.6632211208343506]

# %%
genre_rst_GRU = list()
genre_models = list()

for train in train_list:
  X_train, X_test, y_train, y_test = train_test_split(train, y_genre, test_size=0.3, random_state=73)
  model = buildAttGRU(X_train, 512, 8)
  # %time model.fit(X_train, y_train, batch_size=32, epochs=50, validation_data=(X_test, y_test), callbacks=[es], verbose=0)
  genre_rst_GRU.append(model.evaluate(X_test, y_test))
  genre_models.append(model)
# Out:
# WARNING:tensorflow:Layer gru_19 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# CPU times: user 18.2 s, sys: 1.84 s, total: 20 s
# Wall time: 14.5 s
# 10/10 [==============================] - 0s 3ms/step - loss: 1.6423 - accuracy: 0.4120 - get_f1: 0.2126
# WARNING:tensorflow:Layer gru_21 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# CPU times: user 53.6 s, sys: 6.08 s, total: 59.7 s
# Wall time: 39.1 s
# 10/10 [==============================] - 0s 5ms/step - loss: 1.5075 - accuracy: 0.4651 - get_f1: 0.3857
# WARNING:tensorflow:Layer gru_23 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# CPU times: user 1min 33s, sys: 10.5 s, total: 1min 44s
# Wall time: 1min 7s
# ...

# %%
for rst in genre_rst_GRU:
    print(rst)
# Out:
# [1.642335057258606, 0.4119601249694824, 0.21264639496803284]
# [1.507527232170105, 0.4651162922382355, 0.385731041431427]
# [1.8784520626068115, 0.4451827108860016, 0.387084424495697]
# [1.8882724046707153, 0.42192691564559937, 0.3485655188560486]
# [1.6355607509613037, 0.37541529536247253, 0.24044620990753174]
# [1.5758901834487915, 0.45514950156211853, 0.3676917850971222]
# [1.9293293952941895, 0.37541529536247253, 0.37461939454078674]
# [1.699195384979248, 0.45514950156211853, 0.4402570128440857]
